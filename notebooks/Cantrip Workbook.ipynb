# %% [markdown]
# # Workbook for creating spells
#
# ## Cantrip-like spells, Rank 1, from my FW notes
#
# Target difficulty is 5. These were 1-2 points of difficulty in the FW rules.
#
# This creates the ``fw_cantrips.py`` module and ``fw_cantrips.txt`` RST-format extract.

# %%
from opend6_tools.magic import *

# %%
protection_from_magic = Spell(
        name="Protection from Magic",
        skill="Elemental Alteration",
        notes="Distinct from Shield which prevents the link, this mitigates effects",
        effect=ProtectionEffect("Reduce effect (after a link)", "2D"),
        duration=DurationAspect(measure="1 s"),
        range=RangeAspect(measure="20 m"),
        casting_time=CastingTimeAspect(measure="5 s"),
        speed=SpeedAspect.based_on(("range",), ""),
        other_aspects={
            "incantation": IncantationsAspect("Protection Chant", "litany"),
            "concentration": ConcentrationAspect(measure="5 s"),
        },
        other_conditions=[
            GenericAspect(difficulty=0, description="opposed"),
            GenericAspect(difficulty=0, description="Controller: None"),
        ],
    )
print(display(protection_from_magic))
# Out:
#   name                : 'Protection from Magic'
#   notes               : 'Distinct from Shield which prevents the link, this mitigates effects'
#   skill               : 'Elemental Alteration'
#   difficulty_note     : ''
#   effect              :  +6 ProtectionEffect('Reduce effect (after a link)', '+2D')
#   duration            :  +0 DurationAspect('1 s')
#   range               :  +7 RangeAspect('20 m')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +7 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Protection Chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 s')
#   other_conditions    :
#   -  +0 GenericAspect(0, 'opposed')
#   -  +0 GenericAspect(0, 'Controller: None')
# Effect Details        : [(Decimal('6'), '+2D')]
# Spell Total           : {'effect': 6, 'duration': 0, 'range': 7, 'speed': 7} = 20
# Negative Modifiers    : {'casting_time': 4, 'incantation': 4, 'concentration': 2, 'condition: opposed': 0, 'condition: Controller: None': 0} = 10
# Difficulty            : ⎡(20 - 10) ÷ 2⎤ = 5

# %%
halt = Spell(
        name="Halt",
        skill="Psychic Communication",
        notes="The halt duration is short; an agility check is required to keep from stumbling",
        effect=SkillEffect("Halt! with bonus to overcome mettle", "2D"),
        duration=DurationAspect(measure="2 sec"),
        range=RangeAspect(measure="20 m"),
        casting_time=CastingTimeAspect(measure="5 sec"),
        speed=SpeedAspect.based_on(("range",), ""),
        other_aspects={
            "incantation": IncantationsAspect("Control chant", "litany"),
            "concentration": ConcentrationAspect(measure="5 sec"),
        },
        other_conditions=[
            GenericAspect(difficulty=0, description="Controller: Witan Acumen")
        ],
    )
print(display(halt))
# Out:
#   name                : 'Halt'
#   notes               : 'The halt duration is short; an agility check is required to keep from stumbling'
#   skill               : 'Psychic Communication'
#   difficulty_note     : ''
#   effect              :  +6 SkillEffect('Halt! with bonus to overcome mettle', '+2D')
#   duration            :  +2 DurationAspect('2 sec')
#   range               :  +7 RangeAspect('20 m')
#   casting_time        :  -4 CastingTimeAspect('5 sec')
#   speed               :  +7 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Control chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 sec')
#   other_conditions    :
#   -  +0 GenericAspect(0, 'Controller: Witan Acumen')
# Effect Details        : [(Decimal('6'), '+2D')]
# Spell Total           : {'effect': 6, 'duration': 2, 'range': 7, 'speed': 7} = 22
# Negative Modifiers    : {'casting_time': 4, 'incantation': 4, 'concentration': 2, 'condition: Controller: Witan Acumen': 0} = 10
# Difficulty            : ⎡(22 - 10) ÷ 2⎤ = 6

# %%
illusion_of_rat = Spell(
        name="Illusion of Rat",
        skill="Temperamental Conjuration",
        notes="An autonomous illusion of a large rat",
        effect=SkillEffect("Fear", "3D"),
        duration=DurationAspect(measure="5 min"),
        range=RangeAspect(measure="10 m"),
        casting_time=CastingTimeAspect(measure="5 sec"),
        speed=SpeedAspect.based_on(("range",), ""),
        other_aspects={
            "gestures": GesturesAspect("Illusion Gestures", "simple"),
            "incantation": IncantationsAspect("Illusion Chant", "litany"),
            "concentration": ConcentrationAspect(measure="5 sec"),
            "other_alterant": GenericAspect(
                difficulty=3, description="illusion is moving"
            ),
            "unreal_effect": UnrealEffectAspect.based_on("effect", "difficulty 13"),
        },
        other_conditions=[
            GenericAspect(difficulty=-2, description="illusion limited to 1 color"),
            GenericAspect(difficulty=0, description="Controller: Baelu Charisma"),
        ],
    )
print(display(illusion_of_rat))
# Out:
#   name                : 'Illusion of Rat'
#   notes               : 'An autonomous illusion of a large rat'
#   skill               : 'Temperamental Conjuration'
#   difficulty_note     : ''
#   effect              :  +9 SkillEffect('Fear', '+3D')
#   duration            : +12 DurationAspect('5 min')
#   range               :  +5 RangeAspect('10 m')
#   casting_time        :  -4 CastingTimeAspect('5 sec')
#   speed               :  +5 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - gestures          :  -2 GesturesAspect('Illusion Gestures', 'simple')
#   - incantation       :  -4 IncantationsAspect('Illusion Chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 sec')
#   - other_alterant    :  -3 GenericAspect(3, 'illusion is moving')
#   - unreal_effect     :  -2 UnrealEffectAspect.based_on(('effect',), target='unreal; disbelief difficulty 13')
#   other_conditions    :
#   -  +2 GenericAspect(-2, 'illusion limited to 1 color')
#   -  +0 GenericAspect(0, 'Controller: Baelu Charisma')
# Effect Details        : [(Decimal('9'), '+3D')]
# Spell Total           : {'effect': 9, 'duration': 12, 'range': 5, 'speed': 5} = 31
# Negative Modifiers    : {'casting_time': 4, 'gestures': 2, 'incantation': 4, 'concentration': 2, 'other_alterant': 3, 'unreal_effect': 2, 'condition: illusion limited [...]': 2, 'condition: Controller: Baelu [...]': 0} = 19
# Difficulty            : ⎡(31 - 19) ÷ 2⎤ = 6

# %%
communicate_w_plant_animal = Spell(
        name="Communicate w/ Plant/Animal",
        skill="Divination",
        notes="This will gather a bit of common information",
        effect=SkillEffect("Psionics: gather common info; potentially hostile", "+2D", "extranormal skill"),
        duration=DurationAspect(measure="1 s"),
        range=RangeAspect(measure="20 m"),
        casting_time=CastingTimeAspect(measure="5 s"),
        speed=SpeedAspect.based_on(("range",), ""),
        other_aspects={
            "gestures": GesturesAspect("Touch target", "simple"),
            "incantation": IncantationsAspect("Earth and Water chant", "litany"),
            "concentration": ConcentrationAspect(measure="5 s"),
        },
        other_conditions=[
            GenericAspect(difficulty=0, description="Controller: Witan Acumen")
        ],
    )
print(display(communicate_w_plant_animal))
# Out:
#   name                : 'Communicate w/ Plant/Animal'
#   notes               : 'This will gather a bit of common information'
#   skill               : 'Divination'
#   difficulty_note     : ''
#   effect              : +12 SkillEffect('Psionics: gather common info; potentially hostile', '+2D', 'extranormal skill')
#   duration            :  +0 DurationAspect('1 s')
#   range               :  +7 RangeAspect('20 m')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +7 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - gestures          :  -2 GesturesAspect('Touch target', 'simple')
#   - incantation       :  -4 IncantationsAspect('Earth and Water chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 s')
#   other_conditions    :
#   -  +0 GenericAspect(0, 'Controller: Witan Acumen')
# Effect Details        : [(Decimal('6'), '+2D'), (Decimal('2'), 'extranormal skill')]
# Spell Total           : {'effect': 12, 'duration': 0, 'range': 7, 'speed': 7} = 26
# Negative Modifiers    : {'casting_time': 4, 'gestures': 2, 'incantation': 4, 'concentration': 2, 'condition: Controller: Witan Acumen': 0} = 12
# Difficulty            : ⎡(26 - 12) ÷ 2⎤ = 7

# %%
knock = Spell(
        name="Knock",
        skill="Elemental Alteration",
        notes="This tends to destroy the door",
        effect=DamageEffect("break latch or bar", "4D", "physical damage"),
        duration=DurationAspect(measure="1 s"),
        range=RangeAspect(measure="touch"),
        casting_time=CastingTimeAspect(measure="1 s"),
        speed=SpeedAspect.based_on(("range",), ""),
        other_aspects={"incantation": IncantationsAspect("Earth and Water Chant", "litany")},
        other_conditions=[
            GenericAspect(difficulty=-1, description="limited to wood"),
            GenericAspect(
                difficulty=0, description="Controller: Depends on type of wood"
            ),
        ],
    )
print(display(knock))
# Out:
#   name                : 'Knock'
#   notes               : 'This tends to destroy the door'
#   skill               : 'Elemental Alteration'
#   difficulty_note     : ''
#   effect              : +12 DamageEffect('break latch or bar', '+4D', 'physical damage')
#   duration            :  +0 DurationAspect('1 s')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  +0 CastingTimeAspect('1 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Earth and Water Chant', 'litany')
#   other_conditions    :
#   -  +1 GenericAspect(-1, 'limited to wood')
#   -  +0 GenericAspect(0, 'Controller: Depends on type of wood')
# Effect Details        : [(Decimal('12'), '+4D'), (Decimal('1'), 'physical damage')]
# Spell Total           : {'effect': 12, 'duration': 0, 'range': 0, 'speed': 0} = 12
# Negative Modifiers    : {'casting_time': 0, 'incantation': 4, 'condition: limited to wood': 1, 'condition: Controller: [...]': 0} = 5
# Difficulty            : ⎡(12 - 5) ÷ 2⎤ = 4

# %%
shocking_grasp = Spell(
        name="Shocking Grasp",
        skill="Elemental Alteration: Air + Fire",
        notes="A touch that does 6D damage",
        effect=DamageEffect("Electric Damage", "3D+1", "physical damage", "ignores all armor"),
        duration=DurationAspect(measure="1 s"),
        range=RangeAspect(measure="touch"),
        casting_time=CastingTimeAspect(measure="1 s"),
        speed=SpeedAspect.based_on(("range",), ""),
        other_aspects={
            "gestures": GesturesAspect("Complex motion to grasp", "complex"),
            "incantation": IncantationsAspect("Air and Fire Chant", "litany"),
        },
        other_conditions=[
            GenericAspect(difficulty=0, description="Controller: Hælan Coordination")
        ],
    )
print(display(shocking_grasp))
# Out:
#   name                : 'Shocking Grasp'
#   notes               : 'A touch that does 6D damage'
#   skill               : 'Elemental Alteration: Air + Fire'
#   difficulty_note     : ''
#   effect              : +20 DamageEffect('Electric Damage', '+3D+1', 'physical damage', 'ignores all armor')
#   duration            :  +0 DurationAspect('1 s')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  +0 CastingTimeAspect('1 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - gestures          :  -3 GesturesAspect('Complex motion to grasp', 'complex')
#   - incantation       :  -4 IncantationsAspect('Air and Fire Chant', 'litany')
#   other_conditions    :
#   -  +0 GenericAspect(0, 'Controller: Hælan Coordination')
# Effect Details        : [(Decimal('10'), '+3D+1'), (Decimal('1'), 'physical damage'), (Decimal('2'), 'ignores all armor')]
# Spell Total           : {'effect': 20, 'duration': 0, 'range': 0, 'speed': 0} = 20
# Negative Modifiers    : {'casting_time': 0, 'gestures': 3, 'incantation': 4, 'condition: Controller: Hælan [...]': 0} = 7
# Difficulty            : ⎡(20 - 7) ÷ 2⎤ = 7

# %% [markdown]
# ## Overall Check
#
# The range is around the target, $T$, is $-2 \leq d - T < +3$

# %%
from IPython.display import display, Markdown

display(Markdown('\n\n'.join(
    workbook_validation(globals(), 5)
)))
# Out:
# ## All spells approximately 5 difficulty, 3..8.
#
# 6 Spells
