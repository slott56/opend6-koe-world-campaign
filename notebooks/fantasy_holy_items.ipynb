# %% [markdown]
# # Holy Items pulled from OpenD6 Rules
#
# See page 115.

# %%
from opend6_tools.magic import *
from sphinx.ext import duration

# %% [markdown]
# Warding Holy Symbol: Shaped from metal or wood in a sacred representation, this item helps the user turn away undead creatures (Skill Bonus: Intimidation (R1), +3 to intimidation totals, with Ability Loss (R1), only works on undead beings; Burn-out (R1), can be lost or stolen). Price VD (20 G).

# %%
warding_symbol = Item(
    name = "Warding Holy Symbol",
    notes = "Shaped from metal or wood in a sacred representation, this item helps the user turn away undead creatures",
    effect = SpecialAbilityEffect(SpecialAbilityType.skill_bonus, 1, "+3 to intimidation totals",
        modifications=[
            Limitation(LimitationType.ability_loss, 1, "only works on undead beings"),
            Limitation(LimitationType.burn_out, 1, "can be lost or stolen"),
        ]
    ),
    type="Symbol",
    price="VD (20 G)"
)
warding_symbol.difficulty
# Out:
# 5

# %%
print(display(warding_symbol))
# Out:
#   name                : 'Warding Holy Symbol'
#   notes               : 'Shaped from metal or wood in a sacred representation, this item helps the user turn away undead creatures'
#   type                : 'Symbol'
#   price               : 'VD (20 G)'
#   effect              :  -9 SpecialAbilityEffect(SpecialAbilityType.skill_bonus, 1, '+3 to intimidation totals', modifications=[Limitation(LimitationType.ability_loss, 1, 'only works on undead beings'), Limitation(LimitationType.burn_out, 1, 'can be lost or stolen')])
# Effect Details        : SpecialAbilityEffect based on SpecialAbilityLookup [Modifier(difficulty=Decimal('1'), description='skill_bonus')]
# Spell Total           : {'effect': 9} = 9
# Negative Modifiers    : {} = 0
# Difficulty            : ⎡(9 - 0) ÷ 2⎤ = 5

# %% [markdown]
# Blessed Water or Herbs: Sprinkled on the opponent, this causes harm only to those with evil in their hearts (Natural Magick (R10): Harm to Evil, effect: 5D magical physical damage, range: 10 meters, duration: 2.5 seconds, cast time: 1.5 seconds, Component: blessed water or herbs, Other Condition: Against Evil Only, with Burn-out (R2), one-time use). Price VD (50 G).

# %%
blessed_water = Item(
    name="Blessed Water or Herbs",
    notes="Sprinkled on the opponent, this causes harm only to those with evil in their hearts (Natural Magick (R10): Harm to Evil)",
    effect=DamageEffect(5*D, "physical damage"),
    range=RangeAspect("10m"),
    duration=DurationAspect("2.5sec"),
    casting_time=CastingTimeAspect("1.5sec"),
    other_aspects={
        "components": ComponentsAspect("blessed water or herbs", "rare"),
    },
    other_conditions=[
        GenericAspect(-2, "Against Evil Only"),
        Limitation(LimitationType.burn_out, 2, "one-time use")
    ],
    type="Weapon",
    price="VD (50 G)"
)
blessed_water.difficulty
# Out:
# 7

# %%
print(display(blessed_water))
# Out:
#   name                : 'Blessed Water or Herbs'
#   notes               : 'Sprinkled on the opponent, this causes harm only to those with evil in their hearts (Natural Magick (R10): Harm to Evil)'
#   type                : 'Weapon'
#   price               : 'VD (50 G)'
#   effect              : +15 DamageEffect(5*D, 'physical damage')
#   range               :  +5 RangeAspect('10m')
#   duration            :  +2 DurationAspect('2.5sec')
#   casting_time        :  -1 CastingTimeAspect('1.5sec')
#   other_aspects       :
#   - components        :  -4 ComponentsAspect('blessed water or herbs', 'rare')
#   other_conditions    :
#   - Against Evil Only :  +2 GenericAspect(-2, 'Against Evil Only')
#   - burn_out [...]    :  -2 Limitation(LimitationType.burn_out, 2, 'one-time use')
# Effect Details        : DamageEffect based on DiceUnit [Modifier(difficulty=Decimal('15'), description='5*D')], CharacteristicFactor [Factor(factor=Decimal('1'), description='physical_damage')]
# Spell Total           : {'effect': 15, 'range': 5, 'duration': 2} = 22
# Negative Modifiers    : {'casting_time': 1, 'components': 4, 'condition: Against Evil Only': 2, 'condition: burn_out (R2) one- [...]': 2} = 9
# Difficulty            : ⎡(22 - 9) ÷ 2⎤ = 7
