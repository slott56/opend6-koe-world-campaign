# %% [markdown]
# # Chapter 3 Allies

# %%
librarian_text = """
        Name: Librarian
        Characteristics:
        10	STR	0
        15	DEX	15
        10	CON	0
        10	BODY	0
        10	INT	0
        10	EGO	0
        10	PRE	0
        10	COM	0
        2	PD	0
        2	ED	0
        3	SPD	5
        4	REC	0
        20	END	0
        20	STUN	0
        6	Running	0
        2	Swimming	0
        Cost: 20
        Skills & Abilities:
        7	Conversation	13-
        2	Knowledge	11-
        2	Weapons Familiarity	Group
        5	Streetwise	12-
        7	Stealth	14-
        2	Combat - Flail	+1 OCV
        5	Seduction	12-
        25+ Disadvantage
        -15	Spy for Squire Angler:  Secret Identity,
        -10	Devoted to Squire Angler: Uncommon Situation, Strong Intensity,
        Costs: char skills total disadv base
        20 + 30 = 50 = 25 + 25
        Rolls & Effects:
        Base OCV	5
        Base DCV	5
        Base ECV	3
        Phases	4/8/12
        Lift	100 Kg
        Jump	2 Hexes
        CON Roll	11-
        DEX Roll	12-
        INT Roll	11-
        EGO Roll	11-
"""

library_guard_text = """
        Name: Library Guards
        Characteristics:
        STR:14	DEX:16	CON:11	BODY:12	INT:10
        EGO:12	PRE:10	COM:10	PD:3	ED:2
        SPD:3	REC:5	END:22	STUN:25	Running:6
        Swimming:2
        Powers and Skills: Weapons Familiarity Group,Religion 11-,Combat +2,
        25+ Disadvantages:
        Loyal: Common Situation, Strong Intensity, ; Cruel: Uncommon Situation, Strong Intensity
"""

# %%
import hero

# %%
from opend6_tools.character import *

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(librarian_text))
# Out:
# Character(
#     name='Librarian',
#     physique=Physique(3*D+2, {'stamina': 3*D+1}),
#     agility=Agility(4*D, {'fighting': 1*D}),
#     coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
#     intellect=Intellect(3*D+2, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
#     acumen=Acumen(3*D+2, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
#     charisma=Charisma(3*D+2, {'intimidation': 3*D+1}),
#     body=20,
#     move=10.0,
# )
# | cost | description                              | roll                 |
# |------|------------------------------------------|----------------------|
# |    7 | Conversation                             | 13-                  |
# |    2 | Knowledge                                | 11-                  |
# |    2 | Weapons Familiarity                      | Group                |
# |    5 | Streetwise                               | 12-                  |
# |    7 | Stealth                                  | 14-                  |
# |    2 | Combat - Flail                           | +1 OCV               |
# |    5 | Seduction                                | 12-                  |
#
# Spy for Squire Angler:  Secret Identity,
# Devoted to Squire Angler: Uncommon Situation, Strong Intensity,

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(library_guard_text))
# Out:
# Character(
#     name='Library Guards',
#     physique=Physique(3*D+2, {'stamina': 3*D+2}),
#     agility=Agility(4*D, {'fighting': 1*D}),
#     coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
#     intellect=Intellect(3*D+2, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
#     acumen=Acumen(3*D+2, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
#     charisma=Charisma(3*D+2, {'intimidation': 3*D+1}),
#     body=24,
#     move=10.0,
# )
# | cost | description                              | roll                 |
# |------|------------------------------------------|----------------------|
# |      | Weapons Familiarity Group                |                      |
# |      | Religion                                 | 11-                  |
# |      | Combat                                   | +2                   |
# |      |                                          |                      |
#
# Loyal: Common Situation, Strong Intensity,
#  Cruel: Uncommon Situation, Strong Intensity

# %%
librarian = Character(
    name='Librarian',
    physique=Physique(3*D+2),
    agility=Agility(4*D, {'fighting': 1*D, 'melee combat': 2}),
    coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
    intellect=Intellect(3*D+2, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
    acumen=Acumen(3*D+2, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
    charisma=Charisma(3*D+2, {'intimidation': 3*D+1}),
    extranormal=Magic(2*D),
    body=20,
    move=10,
    advantages=[
        Contacts(2, "Squire Angler"),
    ],
    disadvantages=[
        Devotion(2, "Squire Angler"),
    ],
)
librarian.budget
# Out:
# {'Attributes': 24*D+2, 'Skills': 7*D+2, 'Options': 0*D}

# %%
library_guard = Character(
    name='Library Guards',
    physique=Physique(3*D+2),
    agility=Agility(4*D, {'fighting': 1*D, 'melee combat': 2}),
    coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
    intellect=Intellect(3*D+2, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
    acumen=Acumen(3*D+2, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
    charisma=Charisma(3*D+2, {'intimidation': 3*D+1}),
    body=24,
    move=10,
)
library_guard.budget
# Out:
# {'Attributes': 25*D, 'Skills': 9*D, 'Options': -2*D-2}
