# %%
character = """
    Name: Sir Warrant
    Characteristics:
    15	STR	5
    15	DEX	15
    10	CON	0
    10	BODY	0
    15	INT	5
    15	EGO	10
    20	PRE	10
    18	COM	4
    3	PD	0
    3	ED	1
    3	SPD	5
    5	REC	0
    20	END	0
    23	STUN	0
    6	Running	0
    2	Swimming	0
    Cost: 55
    Skills & Abilities:
    7	Bureaucratics	15-
    9	Combat	+3
    9	High Society	16-
    7	Magic	14-
    7	Oratory	21-
    9	Riding	15-
    3	Well-Connected (Contacts & Favors)
    6	Language	Fluent (w/accent)
    5	Religion	13-
    5	Aristocracy
    3	Low Justice
    10	Wealthy	5M Gs
    75+ Disadvantage
    -10	Reputation: 11- Reputation, Appears to be a loafing buffoon
    -15	Limitation: Common Situation, Strong Intensity, Negotiates everything
    -25	Limitation: Very Common Situation, Total Intensity, Insufferably Superior Attitude
    -10	Rivalry: Professional and Romantic Situation, Wooed same Eastern woman, now banished from White Water
    Costs: char skills total disadv base
    55 + 80 = 135 = 60 + 75
    Background:  Last of the full-blooded, old "Eastern Lords".  This heritage has no advantages, since the monarchy has moved to another city.
    Quote:  <Grunt>
"""

# %%
import hero

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(character))
# Out:
# Character(
#     name='Sir Warrant',
#     description='Last of the full-blooded, old "Eastern Lords".  This heritage has no advantages, since the monarchy has moved to another city.'
#     physique=Physique(4*D, {'stamina': 3*D+1}),
#     agility=Agility(4*D, {'fighting': 1*D}),
#     coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
#     intellect=Intellect(4*D, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
#     acumen=Acumen(4*D, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
#     charisma=Charisma(4*D, {'intimidation': 6*D+2}),
#     body=20,
#     move=10.0,
# )
# | cost | description                              | roll                 |
# |------|------------------------------------------|----------------------|
# |    7 | Bureaucratics                            | 15-                  |
# |    9 | Combat                                   | +3                   |
# |    9 | High Society                             | 16-                  |
# |    7 | Magic                                    | 14-                  |
# |    7 | Oratory                                  | 21-                  |
# |    9 | Riding                                   | 15-                  |
# |    3 | Well-Connected (Contacts & Favors)       |                      |
# |    6 | Language                                 | Fluent (w/accent)    |
# |    5 | Religion                                 | 13-                  |
# |    5 | Aristocracy                              |                      |
# |    3 | Low Justice                              |                      |
# |   10 | Wealthy                                  | 5M Gs                |
#
# Reputation: 11- Reputation, Appears to be a loafing buffoon
# Limitation: Common Situation, Strong Intensity, Negotiates everything
# Limitation: Very Common Situation, Total Intensity, Insufferably Superior Attitude
# Rivalry: Professional and Romantic Situation, Wooed same Eastern woman, now banished from White Water

# %%
from opend6_tools.character import *

# %%
sir_warrant = Character(
    name='Sir Warrant',
    description='Last of the full-blooded, old "Eastern Lords".  This heritage has no advantages, since the monarchy has moved to another city.',
    physique=Physique(4*D),
    agility=Agility(4*D, {'fighting': 1*D, 'combat': 1*D, 'riding': 1*D, 'melee combat': 1*D}),
    coordination=Coordination(4*D, ),
    intellect=Intellect(4*D, {'cultures': 1*D, 'speaking': 2*D}),
    acumen=Acumen(4*D, ),
    charisma=Charisma(4*D, {'intimidation': 6*D+2}),
    extranormal=Magic(3*D+1),
    body=20,
    move=10,
    advantages=[
        Patron(R2, "Earl Hillshire"),
        Authority(R2, "aristocracy"),
        Wealth(R2, "wealthy"),
    ],
    disadvantages=[
        Infamy(R1, "Reputation as loafing buffoon"),
        Quirk(R1, "Negotiates Everything"),
        Quirk(R3, "Insufferable superiority complex"),
    ],
    other_notes="Quote: <grunt>; 'I stand as my people's warrant'",
)
sir_warrant.budget
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sir_warrant = Character(
#       2     name='Sir Warrant',
#       3     description='Last of the full-blooded, old "Eastern Lords".  This heritage has no advantages, since the monarchy has moved to another city.',
#       4     physique=Physique(4*D, {'stamina': 3*D+1}),
#       5     agility=Agility(4*D, {'fighting': 1*D, 'combat': 1*D, 'riding': 1*D}),
#       6     coordination=Coordination(4*D, ),
#       7     intellect=Intellect(4*D, {'cultures': 1*D, 'speaking': 2*D}),
#       8     acumen=Acumen(4*D, ),
#       9     charisma=Charisma(4*D, {'intimidation': 6*D+2}),
#      10     extranormal=Magic(3*D+1),
#      11     body=20,
#      12     move=10,
#      13     advantages=[
#      14         Patron(R2, "Earl Hillshire"),
#      15         Authority(R1, "aristocracy"),
#      16         Wealth(R2, "wealthy"),
#      17     ],
#      18     disadvantages=[
#      19         Infamy(R1, "Reputation as loafing buffoon"),
#      20         Quirk(R1, "Negotiates Everything"),
#      21         Quirk(R3, "Insufferable superiority complex"),
#      22     ],
#      23     other_notes="Quote: <grunt>; 'I stand as my people's warrant'",
#      24 )
#      25 sir_warrant.budget
#
# NameError: name 'Character' is not defined
