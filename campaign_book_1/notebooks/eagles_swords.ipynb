# %% [markdown]
# # Swords from Sir Warrant of Eagles
#
# Swords are special.

# %%
from opend6_tools.character import *

# %% [markdown]
# Ice Knife: 2d6+1K HKA (35), 6.1 per Phase END, 1 OAF (-1), 20 STR Min (-.75), 1 Independent (-2), 1 END is 1/2 (0.25), .5 Variable Advantage (0.5), [Very cold, does extra damage to creatures vulnerable to cold; no damage to creates which are naturally cold], Active Points: 61, Real Cost: 13

# %%
ice_knife = Sword(
    name="Ice Knife",
    description="If it persuades the wielder, there will be a killing rampage over friend and foe alike",
    physique=Physique(1*D),
    agility=Agility(1*D),
    intellect=Intellect(1*D),
    charisma=Charisma(2*D, {"persuasion": 1}),
    special_abilities=[
        NaturalHandWeapon(2*D+1, "+1D damage to creatures vulnerable to cold")
    ],
    disadvantages=[
        AdvantageFlaw(3, "wants to rampage and kill everything.")
    ]
)

# %% [markdown]
# Goblin Death: 2d6+1K HKA (35), 6.3 per Phase END, 1 OAF (-1), 1 Independent (-2), 21 STR Min (-.75), Y Detect (1/2 phase) (3), +2 PER (4), 0 END, 1/2x Armor Piercing DEF (0.5), [Detects Goblinc, Orcs, Hobgoblins and the like with a +2 on any perception roll.], Active Points: 63, Real Cost: 13

# %%
goblin_death = Sword(
    name="Goblin Death",
    description="If it detects goblins but doesn't get to kill them, it sulks and refuses to detect any for a few hours",
    physique=Physique(1*D),
    agility=Agility(1*D),
    intellect=Intellect(1*D),
    charisma=Charisma(2*D),
    special_abilities=[
        NaturalHandWeapon(2*D+1),
        ArmorDefeatingAttack(2, "Reduces armor by -2"),
        ExtraSense(2, "Detects goblins and other creatures from the same realm")
    ],
    disadvantages=[
        AdvantageFlaw(3, "insists on killing the goblins it detects.")
    ]
)

# %%
items = [
    ice_knife,
    goblin_death,
]

# %%
from opend6_tools.character import CharacterOption
help(Disadvantage)
# Out:
# Help on class Disadvantage in module opend6_tools.character:
#
# class Disadvantage(CharacterOption)
#  |  Disadvantage(rank: int, notes: str = '') -> None
#  |
#  |  Base class of all disadvantages.
#  |
#  |  Method resolution order:
#  |      Disadvantage
#  |      CharacterOption
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from CharacterOption:
#  |
#  |  __init__(self, rank: int, notes: str = '') -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self) -> str
#  |      Return repr(self).
#  |
#  |  __str__(self) -> str
#  |      Return str(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from CharacterOption:
#  |
#  |  value
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from CharacterOption:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from CharacterOption:
#  |
#  |  name = 'Character Option'
#  |
#  |  rank_cost = 1
