# %% [markdown]
# # New Keep Enchantments
#
# | Enchantment        | Cost | AP | Effect                 | Side Effect |
# |--------------------|-----|----|------------------------|-------------|
# | Fresh Air          | 1 | 5 | Life Support           | |
# | Gust               | 7 | 30 | TK (STR10), 6 hex line | |
# | Gale Wind          | 13 | 60 | TK (STR20), 6x2 line   | Side Effect (TK STR20) |
# | Glide              | 2 | 10 | Glide 10 hexes         | |
# | Summon Winds       | 6 | 20 | Change Env (8 hexes)   | |
# | Sense Air Currents | 4 | 17 | Detect Movement +2     | |
# | Body of Mist       | 10 | 40 | Desolid                | x2 damage from Air spells | |
# |  Tornado           | 38 | 337 | TK (STR50), 3d6 RKA    | Side Effect 6d6 EB |

# %%
from opend6_tools.magic import *

# %%
fresh_air = Spell(
    name="Fresh Air",
    effect=SpecialAbilityEffect(SpecialAbilityType.accelerated_healing, 2, "Immediate help to the target"),
    duration=DurationAspect("1 sec"),
    range=RangeAspect("touch"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("1 round"),
    other_aspects={
        "incantation": IncantationsAspect("Air Summoning", "litany"),
    },
)
fresh_air.difficulty
# Out:
# 5

# %%
gust = Spell(
    name="Gust",
    effect=DamageEffect("Attack with powerful blast of air", 2*D, "physical damage"),
    duration=DurationAspect("1 sec"),
    range=RangeAspect("self"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("1 round"),
    other_aspects={
        "area_effect": AreaEffectAspect("20m height 4m radius cone"),
        "incantation": IncantationsAspect("Air Summoning", "litany"),
        "concentration": ConcentrationAspect(measure="1 rounds"),
    },
)
gust.difficulty
# Out:
# 9

# %%
gale_of_wind = Spell(
    name="Gale of Wind",
    effect=DamageEffect("Attack with a relentless blast", 2*D, "physical damage", "ignores all armor"),
    duration=DurationAspect("1 sec"),
    range=RangeAspect("self"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("1 round"),
    other_aspects={
        "area_effect": AreaEffectAspect("20m height 8m radius cone"),
        "incantation": IncantationsAspect("Air Summoning", "litany"),
        "concentration": ConcentrationAspect(measure="1 rounds"),
    },
)
gale_of_wind.difficulty
# Out:
# 18

# %%
glide = Spell(
    name="Glide",
    effect=SpecialAbilityEffect(SpecialAbilityType.glider_wings, 3, "can glide from a high place or lift off into a very strong wind"),
    notes="The 'wings' are a hazy outline around the target of the spell; speed is typical movement, 10m per round",
    duration=DurationAspect("2 rounds"),
    range=RangeAspect("touch"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("1 round"),
    other_aspects={
        "incantation": IncantationsAspect("Air Summoning", "litany"),
    }
)
glide.difficulty
# Out:
# 12

# %%
cleansing_breeze = Spell(
    name="Cleansing Breeze",
    effect=SpecialAbilityEffect(SpecialAbilityType.environmental_resistance, 4, "survive smoke or air-born poisons"),
    notes="There's little sense of a breeze, but smoke and poison are much less harmful.",
    duration=DurationAspect("2 minutes"),
    range=RangeAspect("touch"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("1 round"),
    other_aspects={
        'area_effect': AreaEffectAspect('4m radius sphere'),
        "incantation": IncantationsAspect("Air Summoning", "litany"),
        "concentration": ConcentrationAspect(measure="1 round"),
    }
)
cleansing_breeze.difficulty
# Out:
# 16

# %%
sense_air = Spell(
    name="Sense Air",
    skill="Acumen",
    effect=SpecialAbilityEffect(SpecialAbilityType.enhanced_sense, 2, "feel movement"),
    duration=DurationAspect("2 minutes"),
    range=RangeAspect("10 m"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("2 rounds"),
    other_aspects={
        "incantation": IncantationsAspect("Air Summoning", "litany"),
        "concentration": ConcentrationAspect(measure="2 minutes"),
    }

)
sense_air.difficulty
# Out:
# 13

# %%
body_of_mist = Spell(
    name="Body of Mist",
    skill="Physique",
    effect=SpecialAbilityEffect(SpecialAbilityType.intangibility, 2),
    duration=DurationAspect("4 minutes"),
    range=RangeAspect("self"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("2 rounds"),
    other_aspects={
        "incantation": IncantationsAspect("Air Summoning", "litany"),
        "concentration": ConcentrationAspect(measure="2 minutes"),
    },
    other_conditions=[Limitation(LimitationType.side_effect, 2, "double damage from air-based enchantments")]
)
body_of_mist.difficulty
# Out:
# 13

# %%
tornado = Spell(
    name="Tornado",
    effect=DamageEffect("Crushing blast of wind", 6 * D, "physical damage", "ignores all armor"),
    duration=DurationAspect("1 sec"),
    range=RangeAspect("self"),
    speed=SpeedAspect.based_on('range'),
    casting_time=CastingTimeAspect("3 rounds"),
    other_aspects={
        "area_effect": AreaEffectAspect("20m height 8m radius cone"),
        "incantation": IncantationsAspect("Air Summoning", "litany"),
        "concentration": ConcentrationAspect.based_on('casting_time'),
        "feedback": FeedbackAspect(10),
    },
)
tornado.difficulty
# Out:
# 24

# %%
help(LimitationType)
# Out:
# Help on class LimitationType in module opend6_tools.magic2.spells:
#
# class LimitationType(UniqueMatchingEnum)
#  |  LimitationType(*values)
#  |
#  |  The defined Special Ability Limitations, and their costs.
#  |  (See :external:ref:`options.special_abilities.limitations`.)
#  |
#  |  >>> ability = LimitationType.match("Burn-out")
#  |  >>> (ability.metric, ability.name)
#  |  (Decimal('1'), 'burn_out')
#  |
#  |  ..  todo:: Handle the more complex price-per-rank rules implied by the table.
#  |
#  |  Method resolution order:
#  |      LimitationType
#  |      UniqueMatchingEnum
#  |      MatchingEnum
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __new__(cls, value) from enum.Enum
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  LimitationType = <LimitationType.LimitationType: 1>
#  |
#  |  ability_loss = <LimitationType.ability_loss: 2>
#  |
#  |  allergy = <LimitationType.allergy: 3>
#  |
#  |  burn_out = <LimitationType.burn_out: 4>
#  |
#  |  debt = <LimitationType.debt: 5>
#  |
#  |  flaw = <LimitationType.flaw: 6>
#  |
#  |  minor_stigma = <LimitationType.minor_stigma: 7>
#  |
#  |  others_only = <LimitationType.others_only: 8>
#  |
#  |  price = <LimitationType.price: 9>
#  |
#  |  restricted = <LimitationType.restricted: 10>
#  |
#  |  side_effect = <LimitationType.side_effect: 11>
#  |
#  |  singularity = <LimitationType.singularity: 12>
#  |
#  |  super_science = <LimitationType.super_science: 13>
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from enum.EnumType:
#  |
#  |  __contains__(value)
#  |      Return True if `value` is in `cls`.
#  |
#  |      `value` is in `cls` if:
#  |      1) `value` is a member of `cls`, or
#  |      2) `value` is the value of one of the `cls`'s members.
#  |      3) `value` is a pseudo-member (flags)
#  |
#  |  __getitem__(name)
#  |      Return the member matching `name`.
#  |
#  |  __iter__()
#  |      Return members in definition order.
#  |
#  |  __len__()
#  |      Return the number of members (no aliases)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from enum.EnumType:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %%
spells = [
fresh_air, gust, gale_of_wind, glide, cleansing_breeze, sense_air, body_of_mist, tornado
]

# %%
[name for name, thing in globals().items() if isinstance(thing, Spell)]
# Out:
# ['fresh_air',
#  'gust',
#  'gale_of_wind',
#  'glide',
#  'cleansing_breeze',
#  'sense_air',
#  'body_of_mist',
#  'tornado']
