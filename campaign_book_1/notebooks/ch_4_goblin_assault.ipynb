# %% [markdown]
# # Chapter 4 Goblin Assault

# %%
from opend6_tools.character import *

# %%
goblin_greater = Creature(
    name="Greater Goblin",
    description="Inhabitants of the realm of mountains and forests",
    agility=Agility(3 * D+2, {'acrobatics': 2, 'dodge': 2, 'fighting': 2, "melee combat": 2, 'stealth': 2}),
    coordination=Coordination(3 * D+2, {"marksmanship": 2, "throwing": 1}),
    physique=Physique(3 * D+2,
                      {'running': 2, 'stamina': 2}),
    intellect=Intellect(3 * D, {"healing": 2, "scholar": 2, "traps": 2}),
    acumen=Acumen(3 * D, {"crafting": 2, "survival": 2}),
    charisma=Charisma(3 * D, {'command': 2, "intimidation": 1*D}),
    disadvantages=[
        CulturalUnfamiliarity(2, "Lost in human company"),
    ],
    advantages=[
        Equipment(2, "Weapon or survival gear unknown to humans"),
    ],
    special_abilities=[
        CombatSense(2, "Surprise reduced by 4"),
    ],
    realm="Ælvish, mountains and forests",
    armor=["bone and hide armor +1D", "buckler +2",],
    weapons=["sword +1D+2"],
)
print(display(goblin_greater))
# Out:
# {'name': 'Goblin',
#  'occupation': '',
#  'race': '',
#  'gender': '',
#  'age': '',
#  'height': '',
#  'weight': '',
#  'physical_description': '',
#  'agility': Agility(3*D, {'acrobatics': 0*D+2, 'dodge': 0*D+2, 'fighting': 0*D+2, 'melee combat': 0*D+2, 'stealth': 0*D+2}),
#  'intellect': Intellect(3*D, {'healing': 0*D+2, 'scholar': 0*D+2, 'traps': 0*D+2}),
#  'coordination': Coordination(3*D, {'marksmanship': 0*D+2, 'throwing': 0*D+1}),
#  'acumen': Acumen(3*D, {'crafting': 0*D+2, 'survival': 0*D+2}),
#  'physique': Physique(3*D, {'running': 0*D+2, 'stamina': 0*D+2}),
#  'charisma': Charisma(3*D, {'command': 0*D+1, 'intimidation': 0*D+2}),
#  'extranormal': Magic(3*D, {'alteration': 0*D, 'apportation': 0*D, 'conjuration': 0*D, 'divination': 0*D}),
#  'advantages': OptionList(Equipment(rank=2, notes='Weapon or survival gear unknown to humans')),
#  'disadvantages': OptionList(CulturalUnfamiliarity(rank=2, notes='Lost in human company')),
#  'special_abilities': OptionList(CombatSense(rank=2, notes='Surprise reduced by 4')),
#  'equipment': '',
#  'description': 'Inhabitants of the realm of mountains and forests',
#  'realm': 'Ælvish, mountains and forests',
#  'move': 10,
#  'strength_damage': 2*D,
#  'body': 34,
#  'wounds': {'Mortal': '1-2',
#             'Incapacitated': '3-6',
#             'Severe': '7-13',
#             'Wounded': '14-19',
#             'Stunned': '20-26'},
#  'funds': 3*D,
#  'silver': 180,
#  'fate_points': 1,
#  'character_points': 5,
#  'personality': '',
#  'objectives': '',
#  'native_language': '',
#  'other_notes': '',
#  'natural_abilities': OptionList(),
#  'note': '',
#  'Check': {'Attributes': '21D out of 18D',
#            'Skills': '10D out of 7D',
#            'Options': '2D'}}

# %%
goblin = Creature(
    name="Goblin",
    description="Inhabitants of the realm of mountains and forests",
    agility=Agility(3 * D, {'acrobatics': 2, 'dodge': 2, 'fighting': 2, "melee combat": 2, 'stealth': 2}),
    coordination=Coordination(3 * D, {"marksmanship": 2, "throwing": 1}),
    physique=Physique(3 * D,
                      {'running': 2, 'stamina': 2}),
    intellect=Intellect(3 * D, {"healing": 2, "scholar": 2, "traps": 2}),
    acumen=Acumen(3 * D, {"crafting": 2, "survival": 2}),
    charisma=Charisma(2 * D),
    disadvantages=[
        CulturalUnfamiliarity(2, "Lost in human company"),
    ],
    advantages=[
        Equipment(2, "Weapon or survival gear unknown to humans"),
    ],
    special_abilities=[
        CombatSense(2, "Surprise reduced by 4"),
    ],
    realm="Ælvish, mountains and forests",
    armor=["bone and hide armor +1D", "buckler +2",],
    weapons=["sword +1D+2"],
)
print(display(goblin))
# Out:
# {'name': 'Goblin',
#  'occupation': '',
#  'race': '',
#  'gender': '',
#  'age': '',
#  'height': '',
#  'weight': '',
#  'physical_description': '',
#  'agility': Agility(3*D, {'acrobatics': 0*D+2, 'dodge': 0*D+2, 'fighting': 0*D+2, 'melee combat': 0*D+2, 'stealth': 0*D+2}),
#  'intellect': Intellect(3*D, {'healing': 0*D+2, 'scholar': 0*D+2, 'traps': 0*D+2}),
#  'coordination': Coordination(3*D, {'marksmanship': 0*D+2, 'throwing': 0*D+1}),
#  'acumen': Acumen(3*D, {'crafting': 0*D+2, 'survival': 0*D+2}),
#  'physique': Physique(3*D, {'running': 0*D+2, 'stamina': 0*D+2}),
#  'charisma': Charisma(3*D, {'command': 0*D+1, 'intimidation': 0*D+2}),
#  'extranormal': Magic(3*D, {'alteration': 0*D, 'apportation': 0*D, 'conjuration': 0*D, 'divination': 0*D}),
#  'advantages': OptionList(Equipment(rank=2, notes='Weapon or survival gear unknown to humans')),
#  'disadvantages': OptionList(CulturalUnfamiliarity(rank=2, notes='Lost in human company')),
#  'special_abilities': OptionList(CombatSense(rank=2, notes='Surprise reduced by 4')),
#  'equipment': '',
#  'description': 'Inhabitants of the realm of mountains and forests',
#  'realm': 'Ælvish, mountains and forests',
#  'move': 10,
#  'strength_damage': 2*D,
#  'body': 34,
#  'wounds': {'Mortal': '1-2',
#             'Incapacitated': '3-6',
#             'Severe': '7-13',
#             'Wounded': '14-19',
#             'Stunned': '20-26'},
#  'funds': 3*D,
#  'silver': 180,
#  'fate_points': 1,
#  'character_points': 5,
#  'personality': '',
#  'objectives': '',
#  'native_language': '',
#  'other_notes': '',
#  'natural_abilities': OptionList(),
#  'note': '',
#  'Check': {'Attributes': '21D out of 18D',
#            'Skills': '10D out of 7D',
#            'Options': '2D'}}

# %%
dog_guard = Creature(
    name='Dog, Guard',
    agility=Agility(3*D, {'dodge': 6*D, 'fighting': 5*D}),
    coordination=Coordination(1*D),
    physique=Physique(4*D, {'running': 4*D+1, 'lifting': 2*D}),
    intellect=Intellect(1*D),
    acumen=Acumen(2*D, {'search': 3*D, 'tracking': 4*D}),
    charisma=Charisma(2*D, {'intimidation': 5*D, 'mettle': 4*D}),
    move='25',
    # strength_damage='2D',
    body=12,
    natural_abilities=[
        NaturalHandWeapon('teeth (damage +1D)'),
        NaturalAbility('small size (scale modifier 4)'),
    ],
)
print(display(dog_guard))
# Out:
# {'name': 'Dog, Guard',
#  'occupation': '',
#  'race': '',
#  'gender': '',
#  'age': '',
#  'height': '',
#  'weight': '',
#  'physical_description': '',
#  'agility': Agility(3*D, {'dodge': 6*D, 'fighting': 5*D}),
#  'intellect': Intellect(1*D, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
#  'coordination': Coordination(1*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
#  'acumen': Acumen(2*D, {'search': 3*D, 'tracking': 4*D}),
#  'physique': Physique(4*D, {'running': 4*D+1, 'lifting': 2*D}),
#  'charisma': Charisma(2*D, {'intimidation': 5*D, 'mettle': 4*D}),
#  'extranormal': Magic(0*D, {'alteration': 0*D, 'apportation': 0*D, 'conjuration': 0*D, 'divination': 0*D}),
#  'advantages': OptionList(),
#  'disadvantages': OptionList(),
#  'special_abilities': OptionList(),
#  'equipment': '',
#  'description': '',
#  'realm': 'Human realm',
#  'move': '25',
#  'strength_damage': 1*D,
#  'body': 12,
#  'wounds': {'Mortal': '1',
#             'Incapacitated': '2',
#             'Severe': '3-4',
#             'Wounded': '5-6',
#             'Stunned': '7-9'},
#  'funds': 2*D,
#  'silver': 120,
#  'fate_points': 1,
#  'character_points': 5,
#  'personality': '',
#  'objectives': '',
#  'native_language': '',
#  'other_notes': '',
#  'natural_abilities': OptionList(NaturalAbility(notes='teeth (damage +1D)'), NaturalAbility(notes='small size (scale modifier 4)')),
#  'note': '',
#  'Check': {'Attributes': '13D out of 18D',
#            'Skills': '33D+1 out of 7D',
#            'Options': 'Nothing'}}
