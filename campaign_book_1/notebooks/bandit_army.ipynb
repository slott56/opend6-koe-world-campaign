# %% [markdown]
# # The Bandit Army high command

# %%
general_text = """
    Name: Bandit Army General (Knight)
    Characteristics:
    19	STR	9
    19	DEX	27
    15	CON	10
    13	BODY	6
    10	INT	0
    10	EGO	0
    14	PRE	4
    10	COM	0
    4	PD	0
    3	ED	0
    3	SPD	1
    7	REC	0
    30	END	0
    30	STUN	0
    6	Running	0
    2	Swimming	0
    Cost: 57
    Skills & Abilities:
    6	Combat	+2
    2	Weapon Familiarity	Category
    5	Stealth	14-
    5	Interrogation	13-
    1	Transport Familiarity	8-
    5	Animal Handler	12-
    3	Gambling	11-
    5	Survival	12-
    4	Professional Skills	13-
    7	Paramedic	16-

    50+ Disadvantage
    -15	Fear Xorn: Common Situation, Strong Intensity,
    -20	Maniacal: Common Situation, Total Intensity,
        Thinks he invincible
    -15	Ambitious: Common Situation, Strong Intensity,
        Trying to climb the ladder of success, stepping on everyone possible.
    Costs: char skills total disadv base
    57 + 43 = 100 = 50 + 50
    Background:    First Officer in Xorn's Cadre.  Ambitious, professional soldier.  Good KS of his job.  Health and fitness buff.  Goes running and stretching and stuff.
    Quote: I've never let this stop me before.
    Tactics: Knows value of support -- logistics, maintenance, etc.  A healer himself.
"""

colonel_text = """
    Name: Bandit Army Colonel (Squire)
    Characteristics:
    18	STR	8
    19	DEX	27
    16	CON	12
    14	BODY	8
    10	INT	0
    10	EGO	0
    14	PRE	4
    10	COM	0
    6	PD	2
    5	ED	2
    3	SPD	1
    7	REC	0
    32	END	0
    31	STUN	0
    6	Running	0
    2	Swimming	0
    Cost: 64
    Skills & Abilities:
    6	Combat	+2
    2	Weapon Familiarity	Category
    5	Stealth	14-
    5	Interrogation	13-
    1	Transport Familiarity	8-
    7	Gambling	13-
    7	Survival	13-
    3	Professional Skills	12-

    50+ Disadvantage
    -15	Fear Xorn: Common Situation, Strong Intensity,

    -20	Maniacal: Common Situation, Total Intensity,
        Thinks he invincible
    -15	Ambitious: Common Situation, Strong Intensity,
        Trying to climb the ladder of success, stepping on everyone possible.

    Costs: char skills total disadv base
    64 + 36 = 100 = 50 + 50

    Background: Wild-man from the hills, tamed and leading other crazies in Xorn's army.  Chews tobacco, spits, scratches and acts like a country bumpkin.
    Quote: Well, hells bells!
    Tactics: Loves the idea of an all-out fight.
"""

high_mage_text = """
    Name: Bandit Army High Mage
    Characteristics:
    15	STR	5
    17	DEX	21
    16	CON	12
    10	BODY	0
    10	INT	0
    10	EGO	0
    14	PRE	4
    10	COM	0
    3	PD	0
    4	ED	0
    2	SPD	1
    6	REC	0
    32	END	0
    26	STUN	0
    6	Running	0
    2	Swimming	0
    Cost: 43
    Skills & Abilities:
    6	Combat	+2
    2	Weapon Familiarity	Category
    1	Transport Familiarity	8-
    3	Gambling	11-
    3	Professional Skills	12-
    9	Magic	14-

    50+ Disadvantage
    -15	Fear Xorn: Common Situation, Strong Intensity,

    -20	Maniacal: Common Situation, Total Intensity,
        Thinks he invincible
    -15	Ambitious: Common Situation, Strong Intensity,
        Trying to climb the ladder of success, stepping on everyone possible.

    Costs: char skills total disadv base
    43 + 27 = 100 = 50 + 50

    Background: Magician with a craving for large-unit combat.
    Quote: This will teach you humility
    Tactics: Wants to crush a large group with magical power
"""
#
# **Spells**
#
# ..  csv-table::
#
#     War Blast	7	30	6d6 EB	Side Effect (6d6 EB, STUN only)
#     War Bolt	7	30	2d6 RKA	Side Effect (2d6 RKA)
#     Battle Shield	4	16	8 PD/ED Force Field	Side Effect (x1.5 STUN & BODY)
#     Dispel	7	30	8d6 Dispel	Side Effect (Aid 3d6 to opponent)
#     Bravery	7	30	Aid 2d6 PRE	Side Effect (Aid Opponents)
#

mage_text = """
    Name: Bandit Army Mage
    Characteristics:
    STR:10	DEX:15	CON:10	BODY:10	INT:10
    EGO:10	PRE:12	COM:10	PD:2	ED:2
    SPD:2	REC:4	END:20	STUN:20	Running:6
    Swimming:2
    Powers and Skills: Combat +1,Weapon Familiarity Category,Transport Familiarity 8-,Professional Skills 11-,Magic 12-
    25+ Disadvantages:
    Fear Xorn: Common Situation, Not much interaction with the high priest.
    ; Back-stabbing: Common Situation, ; Greedy: Uncommon Situation, Looking for money to carry on magical research;
    Background:
    Wants more money and freedom to research than normal fuedal powers permit.
"""
#
# **Spells**
#
# ..  csv-table::
#
#     War Blast	7	30	6d6 EB	Side Effect (6d6 EB, STUN only)
#     War Bolt	7	30	2d6 RKA	Side Effect (2d6 RKA)
#     Battle Shield	4	16	8 PD/ED Force Field	Side Effect (x1.5 STUN & BODY)
#

# %%
import hero

# %%
from opend6_tools.character import *

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(general_text))
# Out:
# Character(
#     name='Bandit Army General (Knight)',
#     description="First Officer in Xorn's Cadre.  Ambitious, professional soldier.  Good KS of his job.  Health and fitness buff.  Goes running and stretching and stuff.",
#     other_notes="Quote: "I've never let this stop me before."",
#     physique=Physique(4*D, {'stamina': 5*D}),
#     agility=Agility(4*D, {'fighting': 1*D}),
#     coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
#     intellect=Intellect(3*D+2, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
#     acumen=Acumen(3*D+2, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
# ...

# %%
general = Character(
    name='Bandit Army General (Knight)',
    description="First Officer in Xorn's Bandit Army.  Ambitious, professional soldier.  Health and fitness buff: goes running and stretching and stuff.",
    other_notes="""Quote: "I've never let this stop me before." """,
    physique=Physique(4*D, {'stamina': 1*D}),
    agility=Agility(4*D, {'fighting': 1*D, "riding": 1*D, "melee combat": 1*D}),
    coordination=Coordination(4*D),
    intellect=Intellect(3*D+2, {'speaking': 1*D, 'healing': 1*D}),
    acumen=Acumen(3*D+2, {'survival': 1*D, 'tracking': 1*D, 'investigation': 1*D, 'gambling': 1*D}),
    charisma=Charisma(3*D+2, {'intimidation': 4*D+2}),
    body=26,
    move=10.0,
    disadvantages=[
        Devotion(2, "Cult of the Jackal"),
        Employed(2, "Cult of the Jackal"),
        Quirk(2, "Exercie Nut"),
    ]
)
general.budget

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(colonel_text))

# %%
colonel = Character(
    name='Bandit Army Colonel (Squire)',
    description="Wild-man from the hills, tamed and leading other crazies in Xorn's army.  Chews tobacco, spits, scratches and acts like a country bumpkin.",
    other_notes="Quote: 'Well, hells bells!'",
    physique=Physique(4*D, {'stamina': 1*D+1}),
    agility=Agility(4*D, {'fighting': 1*D, "melee combat": 2}),
    coordination=Coordination(4*D),
    intellect=Intellect(3*D+2),
    acumen=Acumen(3*D+2, {'gambling': 1*D, 'hide': 1*D, 'survival': 1*D, 'tracking': 1*D}),
    charisma=Charisma(3*D+2, {'intimidation': 4*D+2}),
    body=28,
    move=10,
    disadvantages=[
        Devotion(2, "Cult of the Jackal"),
        Employed(2, "Cult of the Jackal"),
        Hindrance(3, "Thinks he's invincible"),
        Quirk(2, "Ruthless political climber"),
    ]
)
colonel.budget

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(high_mage_text))

# %%
high_mage = Character(
    name='Bandit Army High Mage',
    description='Magician with a craving for large-unit combat.',
    other_notes="Quote: 'This will teach you humility'",
    physique=Physique(4*D, {'stamina': 1*D+1}),
    agility=Agility(4*D, {'fighting': 0*D+2, 'melee combat': 0*D+2}),
    coordination=Coordination(4*D),
    intellect=Intellect(3*D+2, {'reading/writing': 1*D}),
    acumen=Acumen(3*D+2, {'gambling': 1*D, 'know-how': 1*D,}),
    charisma=Charisma(3*D+2, {'intimidation': 4*D+2}),
    extranormal=Magic(3*D),
    body=20,
    move=10.0,
    disadvantages=[
        Devotion(2, "Cult of the Jackal"),
        Employed(2, "Cult of the Jackal"),
        Quirk(2, "Loves the idea of a fight, not the fighting"),
    ]
)
high_mage.budget

# %%
hero.opend6_seed(hero.HeroCharacter.from_text(mage_text))

# %%
mage = Character(
    name='Bandit Army Mage',
    description='',
    physique=Physique(3*D+2),
    agility=Agility(4*D, {'fighting': 0*D+2}),
    coordination=Coordination(4*D, {'charioteering': 0*D, 'lockpicking': 0*D, 'marksmanship': 0*D, 'pilotry': 0*D, 'sleight of hand': 0*D, 'throwing': 0*D}),
    intellect=Intellect(3*D+2, {'cultures': 0*D, 'devices': 0*D, 'healing': 0*D, 'navigation': 0*D, 'reading/writing': 0*D, 'scholar': 0*D, 'speaking': 0*D, 'trading': 0*D, 'traps': 0*D}),
    acumen=Acumen(3*D+2, {'artist': 0*D, 'crafting': 0*D, 'disguise': 0*D, 'gambling': 0*D, 'hide': 0*D, 'investigation': 0*D, 'know-how': 0*D, 'search': 0*D, 'streetwise': 0*D, 'survival': 0*D, 'tracking': 0*D}),
    charisma=Charisma(3*D+2, {'intimidation': 4*D}),
    extranormal=Magic(2*D),
    body=20,
    move=10.0,
    disadvantages=[
        Devotion(2, "Cult of the Jackal"),
        Employed(2, "Cult of the Jackal"),
        Quirk(2, "Back-stabbing little shitweasel"),
    ]
)
mage.budget
# Out:
# {'Attributes': 24*D+2, 'Skills': 8*D, 'Options': -2*D}

# %% [markdown]
# The men-at-arms

# %%
man_at_arms = Character(
    name='Bandit Army -- Guard, Thug, etc.',
    physique=Physique(3*D,),
    agility=Agility(4*D, {'fighting': 2, 'melee combat': 2}),
    coordination=Coordination(3*D),
    intellect=Intellect(3*D),
    acumen=Acumen(3*D),
    charisma=Charisma(2*D),
    body=24,
    move=10.0,
    special_abilities=[
        NaturalHandWeapon(1*D, "Brutal punch")
    ],
    disadvantages=[
        Devotion(3, "Cult of Jackal"),
        Employed(3, "Jackal Temple"),
        Quirk(2, "Hopes to becomes an agent"),
    ]
)
man_at_arms.budget
