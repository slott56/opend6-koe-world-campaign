# %% [markdown]
# # Draft Transposition Spells
#
# These are unique to the Kingdom of the East rulebook.
#
# - Open Veil
# - Close Veil
# - Astral Projection (possession through veil.)
# - Remote cache
# - Portable cache
#
# This notebook is a draft. The final versions are found in `notebooks/Rank__ Workbook.ipynb` files.

# %%
from opend6_tools.magic import *

# %%
open_veil = Spell(
    name = "Opening the Veil",
    skill = "Transposition",
    notes="Opens the veil; it will remain open for others to pass through.",
    effect=CompositeEffect(
        "Veil Opening",
        Effect("Transposition to new realm (R4)", 40),
        Effect("Adjustments for experience, knowledge, and aids", 20),
    ),
    duration=DurationAspect(measure="5 min"),
    range=RangeAspect(measure="touch"),
    casting_time=CastingTimeAspect(measure="5 s"),
    speed=SpeedAspect.based_on(("range",), ""),
    other_aspects={
        "incantation": IncantationsAspect("Veil Opening Chant", "litany"),
        "concentration": ConcentrationAspect(measure="5 s"),
        "components": ComponentsAspect("any resonating artifacts", "rare"),
    },
    other_conditions=[
        GenericAspect(difficulty=0, description="Controller: None"),
    ],
)
print(display(open_veil))
# Out:
#   name                : 'Opening the Veil'
#   notes               : 'Opens the veil; it will remain open for others to pass through.'
#   skill               : 'Transposition'
#   difficulty_note     : ''
#   effect              : +60 CompositeEffect('Veil Opening', Effect(measure='Transposition to new realm (R4)', difficulty=40), Effect(measure='Adjustments for experience, knowledge, and aids', difficulty=20))
#   duration            : +12 DurationAspect('5 min')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Veil Opening Chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 s')
#   - components        :  -4 ComponentsAspect('any resonating artifacts', 'rare')
#   other_conditions    :
#   -  +0 GenericAspect(0, 'Controller: None')
# ...

# %%
close_veil = Spell(
    name = "Closing the Veil",
    skill = "Transposition",
    notes="Closes the veil, restoring the universe to it's base state.",
    effect=Effect("Transposition to the caster's original realm (R2)", 20),
    duration=DurationAspect(measure="5 min"),
    range=RangeAspect(measure="touch"),
    casting_time=CastingTimeAspect(measure="5 s"),
    speed=SpeedAspect.based_on(("range",), ""),
    other_aspects={
        "incantation": IncantationsAspect("Veil Closing Chant", "litany"),
        "concentration": ConcentrationAspect(measure="5 s"),
        "components": ComponentsAspect("any resonating artifacts", "rare"),
        "variable_duration": VariableDurationAspect("off-only"),
    },
    other_conditions=[
        GenericAspect(difficulty=0, description="Controller: None"),
    ],
)
print(display(close_veil))
# Out:
#   name                : 'Closing the Veil'
#   notes               : "Closes the veil, restoring the universe to it's base state."
#   skill               : 'Transposition'
#   difficulty_note     : ''
#   effect              : +20 Effect(measure="Transposition to the caster's original realm (R2)", difficulty=20)
#   duration            : +12 DurationAspect('5 min')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Veil Closing Chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 s')
#   - components        :  -4 ComponentsAspect('any resonating artifacts', 'rare')
#   - variable_duration :  +4 VariableDurationAspect('off-only')
#   other_conditions    :
#   -  +0 GenericAspect(0, 'Controller: None')
# ...

# %%
astral_projection = Spell(
    name="Astral Projection",
    skill="Transposition and Psychic Communication",
    notes="Mage can see past the veil and use possession on an inhabitant. A mage can subsequently open the veil to bring the possessed creature through.",
    effect=CompositeEffect(
        "Possession and Transposition",
        Effect("Transposition to another realm (R1)", 10),
        SpecialAbilityEffect("Possession: Full", 1),
        Effect("Adjustments for experience, knowledge, and aids", 20),
    ),
    duration=DurationAspect(measure="15 min"),
    range=RangeAspect(measure="touch"),
    casting_time=CastingTimeAspect(measure="5 s"),
    speed=SpeedAspect.based_on(("range",), ""),
    other_aspects={
        "incantation": IncantationsAspect("Veil Closing Chant", "litany"),
        "concentration": ConcentrationAspect(measure="5 s"),
        "components": ComponentsAspect("any resonating artifacts", "rare"),
        "variable_duration": VariableDurationAspect("off-only"),
        "variable_effect": VariableEffectAspect("Can increase to R2 to transfer possessed inhabitant to this realm", 10),
    },
    other_conditions=[
        GenericAspect(difficulty=0, description="Controller: None"),
    ],
)
print(display(astral_projection))
# Out:
#   name                : 'Astral Projection'
#   notes               : 'Mage can see past the veil and use possession on an inhabitant. A mage can subsequently open the veil to bring the possessed creature through.'
#   skill               : 'Transposition and Psychic Communication'
#   difficulty_note     : ''
#   effect              : +60 CompositeEffect('Possession and Transposition', Effect(measure='Transposition to another realm (R1)', difficulty=10), SpecialAbilityEffect('Possession: Full', 1), Effect(measure='Adjustments for experience, knowledge, and aids', difficulty=20))
#   duration            : +15 DurationAspect('15 min')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Veil Closing Chant', 'litany')
#   - concentration     :  -2 ConcentrationAspect('5 s')
# ...

# %%
remote_cache = Spell(
    name="Remote Cache",
    skill="Transposition",
    notes="The mage can reach through a small opening into a known space in another realm to keep things. The other realm location is not 100% safe; a critical failure may mean the cache was moved in the other realm. The opening is centered on a specific architectural feature, like a cupboard in the mage's study.",
    effect=CompositeEffect(
        "Possession and Transposition",
        Effect("Transposition to another realm (R3)", 30),
        MassEffect("Limited to", "50 Kg"),
    ),
    duration=DurationAspect(measure="5 min"),
    range=RangeAspect(measure="touch"),
    casting_time=CastingTimeAspect(measure="5 s"),
    speed=SpeedAspect.based_on(("range",), ""),
    other_aspects={
        "incantation": IncantationsAspect("Veil Opening Chant", "litany"),
        "concentration": ConcentrationAspect(measure="5 s"),
        "components": ComponentsAspect("Fixed location (e.g. cupboard)", "common"),
    },
    other_conditions=[
        GenericAspect(difficulty=0, description="Controller: None"),
        GenericAspect(difficulty=3, description="Multiple previous visits"),
        GenericAspect(difficulty=3,
         description="Small chance of loss"),
    ],
)
print(display(remote_cache))
# Out:
#   name                : 'Remote Cache'
#   notes               : "The mage can reach through a small opening into a known space in another realm to keep things. The other realm location is not 100% safe; a critical failure may mean the cache was moved in the other realm. The opening is centered on a specific architectural feature, like a cupboard in the mage's study."
#   skill               : 'Transposition'
#   difficulty_note     : ''
#   effect              : +38 CompositeEffect('Possession and Transposition', Effect(measure='Transposition to another realm (R3)', difficulty=30), MassEffect('Limited to', '50 kg'))
#   duration            : +12 DurationAspect('5 min')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Veil Opening Chant', 'litany')
# ...

# %%
portable_cache = Spell(
    name="Portable Cache",
    skill="Transposition",
    notes="The mage can reach through a portable container's opening into a known space in another realm to keep things. The other realm location is not 100% safe; a critical failure may mean the cache was moved in the other realm. The opening is centered on something moveable, like a a bag or scrip the mage carries.",
    effect=CompositeEffect(
        "Possession and Transposition",
        Effect("Transposition to another realm (R3)", 30),
        MassEffect("Limited to", "50 Kg"),
    ),
    duration=DurationAspect(measure="5 min"),
    range=RangeAspect(measure="touch"),
    casting_time=CastingTimeAspect(measure="5 s"),
    speed=SpeedAspect.based_on(("range",), ""),
    other_aspects={
        "incantation": IncantationsAspect("Veil Opening Chant", "litany"),
        "concentration": ConcentrationAspect(measure="5 s"),
        "components": ComponentsAspect("Movable artifact (e.g. bag)", "common"),
    },
    other_conditions=[
        GenericAspect(difficulty=0, description="Controller: None"),
    ],
)
print(display(portable_cache))
# Out:
#   name                : 'Portable Cache'
#   notes               : "The mage can reach through a portable container's opening into a known space in another realm to keep things. The other realm location is not 100% safe; a critical failure may mean the cache was moved in the other realm. The opening is centered on something moveable, like a a bag or scrip the mage carries."
#   skill               : 'Transposition'
#   difficulty_note     : ''
#   effect              : +38 CompositeEffect('Possession and Transposition', Effect(measure='Transposition to another realm (R3)', difficulty=30), MassEffect('Limited to', '50 kg'))
#   duration            : +12 DurationAspect('5 min')
#   range               :  +0 RangeAspect('touch')
#   casting_time        :  -4 CastingTimeAspect('5 s')
#   speed               :  +0 SpeedAspect.based_on(('range',), '')
#   other_aspects       :
#   - incantation       :  -4 IncantationsAspect('Veil Opening Chant', 'litany')
# ...

# %%
ranked = workbook_rank(globals())
for r in sorted(ranked):
    print(f"R{r}")
    print()
    for s in ranked[r]:
        print("-", f"{s.name}")
    print()
# Out:
# R2
#
# - Closing the Veil
#
# R3
#
# - Remote Cache
# - Portable Cache
#
# R5
#
# - Opening the Veil
#
# R7
#
# - Astral Projection
